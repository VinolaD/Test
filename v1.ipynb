# %%
import pandas as pd

# %%
df=pd.read_csv("/content/FOOD-DATA-GROUP2.csv")    # It is a supervised machine Learning, it has a categorical valiues.

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0                     food  Caloric Value   Fat  \
# 0               0           0                   eggnog            224  10.6
# 1               1           1               beer light             96   0.0
# 2               2           2           beer budweiser             12   0.0
# 3               3           3      weizenbier erdinger            220  18.0
# 4               4           4     beer light budweiser              9   0.0
# ..            ...         ...                      ...            ...   ...
# 314           314         314           fontina cheese            420  33.6
# 315           315         315  monterey cheese low fat            350  24.4
# 316           316         316             colby cheese            445  36.3
# 317           317         317          american cheese             93   7.9
# 318           318         318              blue cheese            106   8.6
#
# ...

# %%
df1=pd.read_csv("/content/FOOD-DATA-GROUP3.csv")    # It is a supervised ML, it has a categorical values.

# %%
df1
# Out:
#      Unnamed: 0.1  Unnamed: 0                         food  Caloric Value  \
# 0               0           0                    nectarine             66
# 1               1           1               kiwifruit gold             51
# 2               2           2             prickly pear raw              8
# 3               3           3                    pineapple             45
# 4               4           4                        rowan            253
# ..            ...         ...                          ...            ...
# 566           566         566           turkey wing cooked            426
# 567           567         567               goose meat raw           6077
# 568           568         568        turkey breast roasted           3266
# 569           569         569        chicken fajita strips             13
# 570           570         570  crispy chicken strips tyson            145
#
#          Fat  Saturated Fats  Monounsaturated Fats  Polyunsaturated Fats  \
# ...

# %%
df2=pd.read_csv("/content/Gold_Daily  (1).csv") #It is a Supervised ML, it has a categorical values.

# %%
df2
# Out:
#               Date    Price     Open    High      Low      Vol  Change %
# 0     Dec 06, 1994   375.80   375.60   376.5   375.10    0.99K    0.0008
# 1     Dec 07, 1994   376.10   377.00   377.5   375.10    1.88K    0.0008
# 2     Dec 08, 1994   376.60   375.30   376.7   374.80    0.48K    0.0013
# 3     Dec 09, 1994   377.00   375.60   377.0   375.50    0.38K    0.0011
# 4     Dec 12, 1994   377.50   376.80   377.8   376.50    0.07K    0.0013
# ...            ...      ...      ...     ...      ...      ...       ...
# 6881  Dec 01, 2021  1784.30  1777.40  1795.7  1773.70  180.34K    0.0044
# 6882  Dec 02, 2021  1762.70  1783.80  1785.2  1762.20  172.72K   -0.0121
# 6883  Dec 03, 2021  1783.90  1769.40  1788.0  1766.00        -    0.0120
# 6884  Dec 05, 2021  1783.80  1784.45  1789.1  1781.60        -   -0.0001
# 6885  Dec 06, 2021  1778.65  1783.85  1788.3  1776.65        -   -0.0029
#
# [6886 rows x 7 columns]

# %%
df3=pd.read_csv("/content/Gold_Monthly (1).csv") # It is a supervised ML, it has a categorical values.

# %%
df3
# Out:
#        Date    Price     Open    High     Low     Vol.  Change %
# 0    Feb 79   271.60   271.60   271.6   271.6        -    0.0727
# 1    Mar 79   256.60   256.60   256.6   256.6        -   -0.0552
# 2    Apr 79   262.40   262.40   262.4   262.4        -    0.0226
# 3    May 79   290.70   290.70   290.7   290.7        -    0.1079
# 4    Jun 79   293.50   293.50   293.5   293.5        -    0.0096
# ..      ...      ...      ...     ...     ...      ...       ...
# 510  Aug 21  1820.10  1818.60  1837.4  1680.0   35.09K    0.0005
# 511  Sep 21  1758.50  1818.60  1838.7  1723.7   68.13K   -0.0338
# 512  Oct 21  1785.90  1759.10  1817.5  1747.9  107.65K    0.0156
# 513  Nov 21  1776.50  1786.80  1881.9  1761.0    1.31M   -0.0053
# 514  Dec 21  1779.35  1775.15  1794.4  1762.3        -    0.0016
#
# [515 rows x 7 columns]

# %%
df4=pd.read_csv("/content/Gold_Yearly  (1).csv") # It is a supervised ML, it has a categorical values.

# %%
df4
# Out:
#     Year  Average\nClosing Price  Year Open  Year High  Year Low  Year Close  \
# 0   1969                   41.10      41.80      43.75     35.00       35.21
# 1   1970                   35.96      35.13      39.19     34.78       37.38
# 2   1971                   40.80      37.33      43.90     37.33       43.50
# 3   1972                   58.17      43.73      70.00     43.73       64.70
# 4   1973                   97.12      64.99     127.00     64.10      112.25
# 5   1974                  158.76     114.75     197.50    114.75      187.50
# 6   1975                  160.87     185.00     186.25    128.75      140.25
# 7   1976                  124.80     140.35     140.35    103.05      134.55
# 8   1977                  147.84     136.10     168.15    129.40      165.60
# 9   1978                  193.57     168.60     243.65    166.30      224.50
# 10  1979                  307.01     227.15     524.00    216.55      524.00
# ...

# %%
df5=pd.read_csv("/content/World_Energy_By_Country_And_Region_1965_to_2023 (1).csv")
# It is a supervised ML, it has a categorical values.

# %%
df5
# Out:
#                                Country    1965    1966    1967    1968  \
# 0                                  NaN     NaN     NaN     NaN     NaN
# 1                               Canada    5.00    5.32    5.57    5.92
# 2                               Mexico    1.06    1.12    1.14    1.24
# 3                                   US   51.98   54.89   56.80   60.19
# 4                  Total North America   58.04   61.33   63.51   67.36
# ..                                 ...     ...     ...     ...     ...
# 106                                NaN     NaN     NaN     NaN     NaN
# 107                        Total World  156.10  164.64  170.68  180.89
# 108                     of which: OECD  110.23  115.84  120.28  128.10
# 109                           Non-OECD   45.87   48.80   50.40   52.79
# 110                   European Union #   34.03   35.19   36.41   38.98
#
#        1969    1970    1971    1972    1973  ...    2014    2015    2016  \
# ...

# %%
df6=pd.read_csv("/content/diabetes (1).csv") #It is a semi-supervised ML.

# %%
df6
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df7=pd.read_csv("/content/stock_data.csv") #It is a supervised ML, it has a categorical values.

# %%
df7
# Out:
#                                                    Text  Sentiment
# 0     Kickers on my watchlist XIDE TIT SOQ PNK CPW B...          1
# 1     user: AAP MOVIE. 55% return for the FEA/GEED i...          1
# 2     user I'd be afraid to short AMZN - they are lo...          1
# 3                                     MNTA Over 12.00            1
# 4                                      OI  Over 21.37            1
# ...                                                 ...        ...
# 5786  Industry body CII said #discoms are likely to ...         -1
# 5787  #Gold prices slip below Rs 46,000 as #investor...         -1
# 5788  Workers at Bajaj Auto have agreed to a 10% wag...          1
# 5789  #Sharemarket LIVE: Sensex off day’s high, up 6...          1
# 5790  #Sensex, #Nifty climb off day's highs, still u...          1
#
# [5791 rows x 2 columns]

# %%
df9=pd.read_csv("/content/valid_data (1).csv")

# %%
df9
# Out:
#                                                    text  label
# 0     Analyst call of the day for @CNBCPro subscribe...      0
# 1     Loop upgrades CSX to buy, says it's a good pla...      0
# 2     BofA believes we're already in a recession — a...      0
# 3     JPMorgan sees these derivative plays as best w...      0
# 4     Morgan Stanley's Huberty sees Apple earnings m...      0
# ...                                                 ...    ...
# 4112  Dollar bonds of Chinese developers fall as str...      3
# 4113  Longer maturity Treasury yields have scope to ...      3
# 4114  Pimco buys €1bn of Apollo buyout loans from ba...      3
# 4115  Analysis: Banks' snubbing of junk-rated loan f...      3
# 4116  U.S. Treasury seeks information on digital ass...      3
#
# [4117 rows x 2 columns]
